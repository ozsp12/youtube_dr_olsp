# %% [markdown]
# **Author:** Osvaldo L. Santos-Pereira
#
# 🌐 Webpage: https://ozsp12.github.io/
# ✅ GitHub: https://github.com/ozsp12
# 🧪 ResearchGate: https://www.researchgate.net/profile/Osvaldo-Santos-Pereira
# 🔬 Google Scholar: https://scholar.google.com/citations?user=HIZp0X8AAAAJ&hl=en
# 🧾 ORCID: https://orcid.org/0000-0003-2231-517X
# 💼 LinkedIn: https://www.linkedin.com/in/ozsp12
# 🧡 Patreon: https://www.patreon.com/ozsp12
# ✍️ Medium: https://medium.com/@ozsp12
# 𝕏 X (Twitter): https://x.com/ozsp12
# 📱 TikTok: https://www.tiktok.com/@ozsp12
# ▶️ YouTube: https://www.youtube.com/@ozlsp12

# %% [markdown]
# # Introduction: syntax, operations, and basic commands
#
# Python has an active community that develops, updates, and optimizes a large ecosystem of libraries. Libraries provide functions, classes, and methods that can be imported and used in programs. In this lesson, we introduce library imports and use practical examples to present basic Python syntax and operations.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Comments and code

# %%
# To write a comment in code, use the hash symbol # at the beginning of the comment.
# Each new comment line must also start with #.

# The following line is executable code
a = 2 + 2

# This line is also executable code
a

# %%
"""
Triple-quoted strings can span multiple lines. When they appear as standalone expressions, they are often used for explanatory text, while inside functions, classes, or modules they may serve as docstrings. Comments should normally use the # symbol. Clear documentation and comments improve readability and maintainability.
"""

# A line of code
b = 2 * 3

# Another line of code
b

texto = '''Using triple single quotes also creates a multiline string that can be stored in a variable, as in this example.'''

texto

# %% [markdown]
# ## Interactive interpreter and basic operations

# %%
# Addition
1 + 3

# %%
# Subtraction
7 - 9

# %%
# Division
10 / 3

# %%
# Integer division
10 // 3

# %%
# Integer power
10**2

# %%
# Rational power
100**(1/2)

# %% [markdown]
# ## Strings (text)

# %%
# String
"Text"

# %%
# String concatenation
"Airplane " + "Teco " + "Teco"

# %%
# String multiplication
"Airplane " + "Teco"*2

# %%
"Text"[0:3]

# %%
"Textxxx"[:-3]

# %% [markdown]
# ## Print

# %%
print('Hello World!')

# %%
print('Hello', 'World!')

# %%
print('Hello', 'World!',sep = '-')

# %%
print('Hello', 'World!',sep = '+')

# %%
print('Hello', 'World!',sep = '**')

# %%
print('Hello World!')
print('Hello', 'World!')
print('Hello', 'World!', sep = " ")

# %%
print('Hello', 'World', sep = " ", end ='!\nnew text')

# %%
# Without print()
1 + 3
4 * 12
3 / 4

# %%
# With print()
print(1 + 3)
print(4 * 12)
print(3 / 4)

# %%
# Print
print('One times two:', 1 * 2)

# %%
print('Argument 1', 'Argument 2', 'Argument 3', 'Argument 4')

# %%
print('Argument 1,', 'Argument 2,', 'Argument 3,', 'Argument 4,')

# %% [markdown]
# ## Types and variables
#
# Python provides different data types for representing values. Common categories include:
#
# * Numeric data.
# * Text data.
# * Logical data.
#
# Some fundamental Python types are:
#
# * `int`: integer numbers, such as -3, 7, 0, and 2020.
# * `float`: real-valued floating-point numbers, such as -3.2, 1.5, 1e-8, and 3.2e5.
# * `str`: character strings, such as `"Unicamp"` and `"MC102"`.
# * `bool`: Boolean values `True` and `False`.

# %%
print(type(10))

# %%
print(type(3.14))

# %%
print(type('10'))

# %%
print(type(True))

# %%
print(type(False))

# %%
pi = 3.1416
print(pi)

# %%
a = b = c = 3
print(a, b, c)

# %%
a = 2
b = 1
a = b
b = a
print(a,b)

# %%
nota_P1 = 10.0
nota_P2 = 8.5
nota_final = (nota_P1 + nota_P2)/2
print(nota_final, '\n' , type(nota_final))

# %% [markdown]
# ## Mathematical operators
#
# Python provides augmented assignment operators as a compact way to update variables:
#
# * `x += y` is equivalent to `x = x + y`.
# * `x -= y` is equivalent to `x = x - y`.
# * `x *= y` is equivalent to `x = x * y`.
# * `x /= y` is equivalent to `x = x / y`.
# * `x %= y` is equivalent to `x = x % y`.
#
# Operator precedence determines the order in which parts of an expression are evaluated. In simplified form, Python evaluates the operators used in these examples according to the following hierarchy:
#
# * Exponentiation.
# * Unary operators (`+` and `-`).
# * Multiplication, division, floor division, and modulo.
# * Addition and subtraction.
# * Parentheses may be used to explicitly control evaluation order and improve readability.

# %%
a = 100 
a += 150 
print(a)

# %%
a -= 50 
print(a)

# %%
a *= 3 
print(a)

# %%
a /= 30 
print(a)

# %%
# The % operator returns the remainder of the division a % b
a = 11
a %= 3 
print(a) # because 11 = 3*3 + 2

# %%
print((2 + 2) / 2)

# %%
print(2 ** 2 % 2)

# %%
print(2 * 2 + 8 / 2 ** 2)

# %%
print(100 - 99 / 3 % 2)

# %%
'a' + 'b'

# %%
'a' + 'b'*2

# %%
'a'*2 + 'b'

# %%
'a'*2 + 'b'*2

# %%
('a'*2 + 'b')*2

# %%
('a' + 'b')*2
